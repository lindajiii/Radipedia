# %% [markdown]
# # Setup

# %%
import os
import glob
import time
import json
from IPython.display import display
import pandas as pd
from PIL import Image

import gmft
from gmft.pdf_bindings import PyPDFium2Document
from gmft.auto import CroppedTable, TableDetector
from gmft._rich_text.rich_page import FormattedPage
detector = TableDetector()
from gmft.auto import AutoTableFormatter
from gmft.auto import AutoFormatConfig
config = AutoFormatConfig()
config.semantic_spanning_cells = True # [Experimental] better spanning cells
config.enable_multi_header = True # multi-indices
formatter = AutoTableFormatter(config)

def ingest_pdf(pdf_path) -> list[CroppedTable]:
    doc = PyPDFium2Document(pdf_path)

    tables = []
    for page in doc:
        tables += detector.extract(page)
    return tables, doc

# %%
import math
from PIL import Image

import pandas as pd
import pickle
from pydantic import BaseModel
from typing import Any
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Checking pickle files

# %%
# table_position_path = "./lea_storage/table_position.csv"
text_position_path = "./linda_storage/table_title_all_book.pkl"
with open(text_position_path, 'rb') as file:
    text_pos = pickle.load(file)

# %%
text_pos[:5]
# Out:
# [{'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 17,
#   'position': (60.0, 58.0, 215.26011657714844, 70.0),
#   'text': 'Table 1-1 Extrinsic Esophageal Masses'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 16,
#   'position': (306.0, 58.0, 476.4881591796875, 70.0),
#   'text': 'Table 1-2 Esophageal Submucosal Masses'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 18,
#   'position': (42.0, 58.0, 244.8881072998047, 70.0),
#   'text': 'Table 1-3 Submucosal Benign Esophageal Tumors'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 20,
#   'position': (306.0,
#    229.89398193359375,
#    488.2601623535156,
#    241.89398193359375),
#   'text': 'Table 1-4 Esophageal Mucosal Abnormalities'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 21,
#   'position': (60.0, 160.7559814453125, 189.44808959960938, 172.7559814453125),
#   'text': 'Table 1-5 Causes of Esophagitis'}]

# %%
# Load book table
table_position_path = "./linda_storage/processed_books_extracted_tablesv4/Radiology Illustrated_ Hepatobiliary and Pancreatic Radiology ( PDFDrive )/table_positions_Radiology Illustrated_ Hepatobiliary and Pancreatic Radiology ( PDFDrive ).csv"
table_pos = pd.read_csv(table_position_path)
table_pos['pos'] = list(zip(table_pos['x0'], table_pos['y0']))
table_pos.head()
# Out:
#                                             pdf_name  page_number  \
# 0  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...            4
# 1  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           19
# 2  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           23
# 3  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           29
# 4  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           39
#
#    table_index         x0         y0                                      pos  \
# 0            1  74.617561  72.363022   (74.61756134033203, 72.36302185058594)
# 1            2  55.261497  69.506111  (55.261497497558594, 69.50611114501953)
# 2            3  54.445557  72.900429     (54.445556640625, 72.90042877197266)
# 3            4  55.111008  73.805336   (55.11100769042969, 73.80533599853516)
# 4            5  55.771336  74.529961   (55.77133560180664, 74.52996063232422)
#
#                                           image_path  \
# 0  ./linda_storage/processed_books_extracted_tabl...
# 1  ./linda_storage/processed_books_extracted_tabl...
# 2  ./linda_storage/processed_books_extracted_tabl...
# 3  ./linda_storage/processed_books_extracted_tabl...
# 4  ./linda_storage/processed_books_extracted_tabl...
#
#                                             csv_path
# 0  ./linda_storage/processed_books_extracted_tabl...
# 1  ./linda_storage/processed_books_extracted_tabl...
# 2  ./linda_storage/processed_books_extracted_tabl...
# 3  ./linda_storage/processed_books_extracted_tabl...
# 4  ./linda_storage/processed_books_extracted_tabl...

# %%
table_pos['pdf_name'][300]
# Out:
# 'Radiology Illustrated_ Hepatobiliary and Pancreatic Radiology ( PDFDrive )_mainpages.pdf'

# %%
for text in text_pos:
    text['page_num'] += 1
    df = table_pos[table_pos['page_number']==text['page_num']]
    if len(df) > 0:
        df['distance'] = df['pos'].apply(lambda x: math.dist(x, text['position'][0:2]))
        page_num = text['page_num']
        idx = df.loc[df['distance'].idxmin()]['table_index']
        pdf_name = text['book_title'][:-10]
        table_path = f"./linda_storage/processed_books_extracted_tablesv4/{pdf_name}/images/{page_num}_{idx}_{pdf_name}.png"
        df_path = f"./linda_storage/processed_books_extracted_tablesv4/{pdf_name}/tables/{page_num}_{idx}_{pdf_name}.csv"
        text['image_path'] = table_path
        text['df_path'] = df_path

# %% [markdown]
# # updated matching code

# %%
# Example book title to filter
book_to_filter = "gastrointestinal-imaging-the-requisites-fourth-edition_mainpages"

# Filter text_pos by the given book title
filtered_text_pos = [text for text in text_pos if text['book_title'] == book_to_filter]
filtered_text_pos[0]
# Out:
# {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#  'page_num': 17,
#  'position': (60.0, 58.0, 215.26011657714844, 70.0),
#  'text': 'Table 1-1 Extrinsic Esophageal Masses'}

# %%
# Example book title to filter
book_to_filter = "gastrointestinal-imaging-the-requisites-fourth-edition_mainpages"

# Filter text_pos by the given book title
filtered_text_pos = [text for text in text_pos if text['book_title'] == book_to_filter]

# Normalize pdf_name by removing '.pdf' suffix for matching
for text in filtered_text_pos:
    pdf_name = table_pos['pdf_name'][:-4]  # Removing '.pdf'
    
    # Filter table_pos by matching book title (normalized pdf_name) and page number
    matching_tables = table_pos[
        (table_pos['page_number'] == text['page_num']) & 
        (table_pos['book_title'] == text['book_title'])
    ]

    if len(matching_tables) > 0:
        # Calculate distances and find the closest table
        matching_tables['distance'] = matching_tables['pos'].apply(
            lambda x: math.dist(x, text['position'][0:2])
        )
        idx = matching_tables.loc[matching_tables['distance'].idxmin()]['table_index']

        # Construct paths
        page_num = text['page_num']
        table_path = f"./linda_storage/processed_books_extracted_tablesv4/{pdf_name}/images/{page_num}_{idx}_{pdf_name}.png"
        df_path = f"./linda_storage/processed_books_extracted_tablesv4/{pdf_name}/tables/{page_num}_{idx}_{pdf_name}.csv"

        # Add paths to the text dictionary
        text['image_path'] = table_path
        text['df_path'] = df_path

# Output the filtered dataset with paths added
print(filtered_text_pos)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'book_title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[181], line 14
#       9 pdf_name = table_pos['pdf_name'][:-4]  # Removing '.pdf'
#      11 # Filter table_pos by matching book title (normalized pdf_name) and page number
#      12 matching_tables = table_pos[
#      13     (table_pos['page_number'] == text['page_num']) &
# ---> 14     (table_pos['book_title'] == text['book_title'])
#      15 ]
#      17 if len(matching_tables) > 0:
#      18     # Calculate distances and find the closest table
#      19     matching_tables['distance'] = matching_tables['pos'].apply(
#      20         lambda x: math.dist(x, text['position'][0:2])
#      21     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'book_title'

# %%
text_pos[:5]
# Out:
# [{'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 14,
#   'position': (60.0, 58.0, 215.26011657714844, 70.0),
#   'text': 'Table 1-1 Extrinsic Esophageal Masses'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 17,
#   'position': (306.0, 58.0, 476.4881591796875, 70.0),
#   'text': 'Table 1-2 Esophageal Submucosal Masses',
#   'image_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/images/17_3_gastrointestinal-imaging-the-requisites-fourth-edition.png',
#   'df_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/tables/17_3_gastrointestinal-imaging-the-requisites-fourth-edition.csv'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 19,
#   'position': (42.0, 58.0, 244.8881072998047, 70.0),
#   'text': 'Table 1-3 Submucosal Benign Esophageal Tumors',
#   'image_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/images/19_2_gastrointestinal-imaging-the-requisites-fourth-edition.png',
#   'df_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/tables/19_2_gastrointestinal-imaging-the-requisites-fourth-edition.csv'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 21,
#   'position': (306.0,
#    229.89398193359375,
#    488.2601623535156,
#    241.89398193359375),
#   'text': 'Table 1-4 Esophageal Mucosal Abnormalities'},
#  {'book_title': 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages',
#   'page_num': 22,
#   'position': (60.0, 160.7559814453125, 189.44808959960938, 172.7559814453125),
#   'text': 'Table 1-5 Causes of Esophagitis',
#   'image_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/images/22_2_gastrointestinal-imaging-the-requisites-fourth-edition.png',
#   'df_path': './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/tables/22_2_gastrointestinal-imaging-the-requisites-fourth-edition.csv'}]

# %% [markdown]
# # Loading book directories

# %%
# Specify the directory path
directory_path = './pdf_data/LIRADS_books_processed_v2'
file_paths = glob.glob(directory_path + '/**/*_mainpages.pdf', recursive=True)

# Initialize empty lists to store data
document_type = []
book_names = []  # For the modified filename (book_name)
full_paths = []

for file_path in file_paths:
    dirname, filename = os.path.split(file_path)
    
    # Set 'dirname' to 'book' for all entries
    document_type.append('Book')
    
    # Extract the book name by removing '_mainpages.pdf'
    book_name = filename
    # book_name = filename.replace('_mainpages.pdf', '')
    book_names.append(book_name)
    
    full_paths.append(file_path)

# Create a DataFrame
books = pd.DataFrame({
    'document_type': document_type,  # 'dirname' becomes 'book'
    'book_name': book_names,  # 'filename' becomes 'book_name'
    'full_path': full_paths
})

# Convert full_path to list if needed
dirname_list = books['full_path'].tolist()

# Print the DataFrame
print(books)
# Out:
#   document_type                                          book_name  \
# 0          Book  Diagnostic Imaging_ Gastrointestinal ( PDFDriv...
# 1          Book  Liver imaging _ MRI with CT correlation ( PDFD...
# 2          Book  Mayo Clinic Gastrointestinal Imaging Review ( ...
# 3          Book  Radiology Illustrated_ Hepatobiliary and Pancr...
# 4          Book  CT and MRI of the Whole Body, 2-Volume Set, 6e...
# 5          Book  gastrointestinal-imaging-the-requisites-fourth...
#
#                                            full_path
# 0  ./pdf_data/LIRADS_books_processed_v2/Diagnosti...
# 1  ./pdf_data/LIRADS_books_processed_v2/Liver ima...
# 2  ./pdf_data/LIRADS_books_processed_v2/Mayo Clin...
# 3  ./pdf_data/LIRADS_books_processed_v2/Radiology...
# 4  ./pdf_data/LIRADS_books_processed_v2/CT and MR...
# 5  ./pdf_data/LIRADS_books_processed_v2/gastroint...

# %%
pdfs_folder='pdf_data/LIRADS_books_processed/'
pdf_list= books['book_name']
print(pdf_list)
# Out:
# 0    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...
# 1    Liver imaging _ MRI with CT correlation ( PDFD...
# 2    Mayo Clinic Gastrointestinal Imaging Review ( ...
# 3    Radiology Illustrated_ Hepatobiliary and Pancr...
# 4    CT and MRI of the Whole Body, 2-Volume Set, 6e...
# 5    gastrointestinal-imaging-the-requisites-fourth...
# Name: book_name, dtype: object

# %% [markdown]
# # Function for deleting folders if files are wrongly generated

# %%
# import os
# import shutil

# # Specify the directory path
# directory_path = './linda_storage/processed_books_extracted_tablesv4/'

# # Loop through each item in the directory
# for item in os.listdir(directory_path):
#     item_path = os.path.join(directory_path, item)

#     # Check if the item is a directory, if so, delete it
#     if os.path.isdir(item_path):
#         shutil.rmtree(item_path)  # Deletes the directory and its contents

# %% [markdown]
#  # Old Process Books code

# %%
# import os
# import time
# import pandas as pd

# # Initialize the variables to track time
# _total_detect_time = 0
# _total_detect_num = 0
# _total_format_time = 0
# _total_format_num = 0
# table_details = []  # List to store table details (page no, index, coordinates)

# # Process each PDF in the list
# for paper in pdf_list:
    
#     results = []
#     images = []
#     dfs = []
    
#     start = time.time()
    
#     # Ingest the PDF file and extract tables
#     tables, doc = ingest_pdf('./pdf_data/LIRADS_books_processed/' + paper)
#     num_pages = len(doc)
#     end_detect = time.time()

#     formatted_tables = []

#     # Create a directory for each PDF book
#     book_folder = f'./linda_storage/processed_books_extracted_tablesv4/{paper[:-14]}'
#     images_folder = os.path.join(book_folder, 'images')
#     tables_folder = os.path.join(book_folder, 'tables')
    
#     # Ensure directories for images and tables exist
#     os.makedirs(images_folder, exist_ok=True)
#     os.makedirs(tables_folder, exist_ok=True)
    
#     # Loop over the extracted tables
#     for i, table in enumerate(tables):
#         ft = formatter.extract(table)  # Process the table using the formatter
        
#         # Extract the table's information in dictionary format
#         table_info = ft.to_dict()
        
#         # Get the page number from the dictionary
#         page_number = table_info.get('page_no', 'unknown') + 1  # As pg no starts at 0
#         z = i + 1  # As i starts at 0

#         # Get table coordinates (bounding box)
#         bbox = table_info.get('bbox', (0, 0, 0, 0))  # Ensure bbox exists, default to (0, 0, 0, 0)

#         # Save the table details (page number, table index, and coordinates)
#         table_details.append({
#             'pdf_name': paper,
#             'page_number': page_number,
#             'table_index': z,
#             'x0': bbox[0],
#             'y0': bbox[1],
#             'pos': (bbox[0], bbox[1])
#             # 'x1': bbox[2],
#             # 'y1': bbox[3]
#         })
        
#         # Try to append the dataframe and handle any exceptions
#         try:
#             df = ft.df()
#             dfs.append(df)

#             # Save the dataframe to CSV in the tables folder
#             table_filename = f"{page_number}_{z}_{paper[:-14]}.csv"
#             table_path = os.path.join(tables_folder, table_filename)
#             df.to_csv(table_path, index=False)
#         except Exception as e:
#             print(e)
#             dfs.append(None)
        
#         formatted_tables.append(ft)
        
#         # Save the image corresponding to the table in the images folder
#         image = ft.image()
#         images.append(image)
        
#         # Generate the image filename with page number and table index
#         image_filename = f"{page_number}_{z}_{paper[:-14]}.png"
#         image_path = os.path.join(images_folder, image_filename)
        
#         # Save the image
#         image.save(image_path)
    
#     end_format = time.time()

#     # Close the document after processing
#     doc.close()
    
#     # Store results and print time details
#     results += formatted_tables
#     print(f"Paper: {paper}\nDetect time: {end_detect - start:.3f}s for {num_pages} pages")
#     print(f"Format time: {end_format - end_detect:.3f}s for {len(tables)} tables\n")
    
#     _total_detect_time += end_detect - start
#     _total_detect_num += num_pages
#     _total_format_time += end_format - end_detect
#     _total_format_num += len(tables)

#     # Save table details (coordinates) as a DataFrame for this PDF
#     details_df = pd.DataFrame(table_details)
#     details_df.to_csv(f'{book_folder}/table_positions_{paper[:-14]}.csv', index=False)

# # Print macro statistics for time tracking
# print(f"Macro: {_total_detect_time/_total_detect_num:.3f} s/page and {_total_format_time/_total_format_num:.3f} s/table")
# Out:
# The identified boxes have significant overlap: 27.20% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 30.26% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 43.74% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.53% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 25.85% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.29% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 21.79% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.45% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 29.11% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 92.40% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 80.82% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 314.34% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 82.76% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 84.80% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 117.38% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 81.44% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 103.37% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 96.07% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 85.26% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 86.48% of area is overlapping (Max is 20.00%)
# Paper: gastrointestinal-imaging-the-requisites-fourth-edition_mainpages.pdf
# Detect time: 32.302s for 408 pages
# Format time: 9.633s for 99 tables
#
# Macro: 0.079 s/page and 0.097 s/table

# %% [markdown]
# # Updated Book code
# - to include table img path, table df path and pos

# %%
import os
import time
import pandas as pd

# Initialize the variables to track time
_total_detect_time = 0
_total_detect_num = 0
_total_format_time = 0
_total_format_num = 0
table_details = []  # List to store table details (page no, index, coordinates, paths)

# Process each PDF in the list
for paper in pdf_list:
    
    results = []
    images = []
    dfs = []
    
    start = time.time()
    
    # Ingest the PDF file and extract tables
    tables, doc = ingest_pdf(f'./pdf_data/LIRADS_books_processed_v2/{paper}')
    num_pages = len(doc)
    end_detect = time.time()

    formatted_tables = []

    # Create a directory for each PDF book
    book_folder = f'./linda_storage/processed_books_extracted_tablesv4/{paper[:-14]}'
    images_folder = os.path.join(book_folder, 'images')
    tables_folder = os.path.join(book_folder, 'tables')
    
    # Ensure directories for images and tables exist
    os.makedirs(images_folder, exist_ok=True)
    os.makedirs(tables_folder, exist_ok=True)
    
    # Loop over the extracted tables
    for i, table in enumerate(tables):
        ft = formatter.extract(table)  # Process the table using the formatter
        
        # Extract the table's information in dictionary format
        table_info = ft.to_dict()
        
        # Get the page number from the dictionary
        page_number = table_info.get('page_no', 'unknown') + 1  # As pg no starts at 0
        z = i + 1  # As i starts at 0

        # Get table coordinates (bounding box)
        bbox = table_info.get('bbox', (0, 0, 0, 0))  # Ensure bbox exists, default to (0, 0, 0, 0)

        # Generate filenames for the image and CSV
        image_filename = f"{page_number}_{z}_{paper[:-14]}.png"
        image_path = os.path.join(images_folder, image_filename)

        table_filename = f"{page_number}_{z}_{paper[:-14]}.csv"
        table_path = os.path.join(tables_folder, table_filename)
        
        # Try to append the dataframe and handle any exceptions
        try:
            df = ft.df()
            dfs.append(df)
            
            # Save the dataframe to CSV in the tables folder
            df.to_csv(table_path, index=False)
        except Exception as e:
            print(e)
            dfs.append(None)
        
        # Save the image corresponding to the table in the images folder
        image = ft.image()
        images.append(image)
        image.save(image_path)

        # Save the table details including paths for the image and CSV
        table_details.append({
            'pdf_name': paper,
            'page_number': page_number,
            'table_index': z,
            'x0': bbox[0],
            'y0': bbox[1],
            'pos': (bbox[0], bbox[1]),
            'image_path': image_path,
            'csv_path': table_path
        })

        formatted_tables.append(ft)
    
    end_format = time.time()

    # Close the document after processing
    doc.close()
    
    # Store results and print time details
    results += formatted_tables
    print(f"Paper: {paper}\nDetect time: {end_detect - start:.3f}s for {num_pages} pages")
    print(f"Format time: {end_format - end_detect:.3f}s for {len(tables)} tables\n")
    
    _total_detect_time += end_detect - start
    _total_detect_num += num_pages
    _total_format_time += end_format - end_detect
    _total_format_num += len(tables)

    # Save table details (coordinates and paths) as a DataFrame for this PDF
    details_df = pd.DataFrame(table_details)
    details_df.to_csv(f'{book_folder}/table_positions_{paper[:-14]}.csv', index=False)

# Print macro statistics for time tracking
print(f"Macro: {_total_detect_time/_total_detect_num:.3f} s/page and {_total_format_time/_total_format_num:.3f} s/table")
# Out:
# The identified boxes have significant overlap: 41.64% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.02% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.08% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.20% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.77% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.30% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.94% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.56% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.24% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.16% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.06% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 34.05% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.52% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.23% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.96% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.76% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.35% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.97% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.93% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.71% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.10% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.79% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.06% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.85% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The header is not included as a row. Consider adding it back as a row.
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.52% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.68% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.51% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.26% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.74% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.65% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.22% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 29.45% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.05% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 46.06% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.10% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.35% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 30.72% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.66% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.49% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 32.22% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 43.92% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.00% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.76% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.28% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.91% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.72% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.91% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.38% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.62% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.24% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.47% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 30.12% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.38% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 32.00% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.42% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 36.99% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.46% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.12% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.92% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.30% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.29% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.53% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.95% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.42% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.16% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.68% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.77% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.36% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.06% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.21% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 42.28% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.48% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.05% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.20% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.67% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.36% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 45.99% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.57% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.39% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.49% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 35.47% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 23.73% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.25% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.42% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 36.00% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.76% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.54% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.40% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 39.16% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.41% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.99% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.43% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.56% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.24% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.21% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.71% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 32.96% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.29% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.07% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.04% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.91% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 43.35% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.41% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.24% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.26% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.38% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.58% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.39% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.16% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.28% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.18% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.00% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.13% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.64% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.80% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 35.18% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 31.23% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.88% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.60% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.97% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.26% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.98% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 36.39% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.81% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.08% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.09% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.33% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 33.62% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.76% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.20% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.39% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.16% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 40.28% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.90% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.48% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.75% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.82% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 42.13% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.65% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 31.62% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.82% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 41.61% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.38% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.60% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.89% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 43.17% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.87% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 43.93% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 48.10% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.61% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.62% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.74% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.06% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.16% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.23% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.50% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 37.89% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 44.71% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.87% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.30% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.68% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.86% of area is overlapping (Max is 20.00%)
# The header is not included as a row. Consider adding it back as a row.
# The identified boxes have significant overlap: 35.53% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.12% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 36.05% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.18% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.39% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.56% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.79% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.70% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.55% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.96% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.80% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.38% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 34.02% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.19% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 37.87% of area is overlapping (Max is 20.00%)
# Paper: Diagnostic Imaging_ Gastrointestinal ( PDFDrive )_mainpages.pdf
# Detect time: 76.589s for 1071 pages
# Format time: 23.579s for 209 tables
#
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 90.54% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# Paper: Liver imaging _ MRI with CT correlation ( PDFDrive )_mainpages.pdf
# Detect time: 18.125s for 303 pages
# Format time: 1.648s for 18 tables
#
# The header is not included as a row. Consider adding it back as a row.
# Paper: Mayo Clinic Gastrointestinal Imaging Review ( PDFDrive )_mainpages.pdf
# Detect time: 40.889s for 720 pages
# Format time: 4.283s for 53 tables
#
# The identified boxes have significant overlap: 38.56% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 38.01% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.21% of area is overlapping (Max is 20.00%)
# Paper: Radiology Illustrated_ Hepatobiliary and Pancreatic Radiology ( PDFDrive )_mainpages.pdf
# Detect time: 57.553s for 817 pages
# Format time: 2.344s for 22 tables
#
# The identified boxes have significant overlap: 38.65% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.17% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.77% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 86.89% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 43.64% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 49.36% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.78% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.89% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 42.66% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.31% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.55% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 47.09% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.77% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.59% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 39.29% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 40.36% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 31.38% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 35.81% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 35.33% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 44.52% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 50.12% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 42.99% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.01% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.35% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 32.94% of area is overlapping (Max is 20.00%)
# Invoking large table row guess! set TATRFormatConfig.force_large_table_assumption to False to disable this.
# The identified boxes have significant overlap: 36.99% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.87% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.52% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 107.94% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 27.35% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 21.13% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 25.94% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 35.45% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 50.95% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.51% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 38.39% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 41.15% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 31.36% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.73% of area is overlapping (Max is 20.00%)
# Paper: CT and MRI of the Whole Body, 2-Volume Set, 6e, Volume I ( PDFDrive )_mainpages.pdf
# Detect time: 103.378s for 1188 pages
# Format time: 9.993s for 99 tables
#
# The identified boxes have significant overlap: 27.20% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 30.26% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 43.74% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 36.53% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 25.85% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 33.29% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 21.79% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 34.45% of area is overlapping (Max is 20.00%)
# The identified boxes have significant overlap: 29.11% of area is overlapping (Max is 20.00%)
# Paper: gastrointestinal-imaging-the-requisites-fourth-edition_mainpages.pdf
# Detect time: 32.158s for 405 pages
# Format time: 8.070s for 88 tables
#
# Macro: 0.073 s/page and 0.102 s/table

# %%
path = "./linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/table_positions_gastrointestinal-imaging-the-requisites-fourth-edition.csv"

# %%
path
# Out:
# './linda_storage/processed_books_extracted_tablesv4/gastrointestinal-imaging-the-requisites-fourth-edition/table_positions_gastrointestinal-imaging-the-requisites-fourth-edition.csv'

# %%
table_pos['pdf_name'][487]
# Out:
# 'gastrointestinal-imaging-the-requisites-fourth-edition_mainpages.pdf'

# %%
table_pos = pd.read_csv(path)
table_pos
# Out:
#                                               pdf_name  page_number  \
# 0    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...            4
# 1    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           19
# 2    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           23
# 3    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           29
# 4    Diagnostic Imaging_ Gastrointestinal ( PDFDriv...           39
# ..                                                 ...          ...
# 484  gastrointestinal-imaging-the-requisites-fourth...          364
# 485  gastrointestinal-imaging-the-requisites-fourth...          371
# 486  gastrointestinal-imaging-the-requisites-fourth...          371
# 487  gastrointestinal-imaging-the-requisites-fourth...          377
# 488  gastrointestinal-imaging-the-requisites-fourth...          385
#
#      table_index          x0          y0  \
# 0              1   74.617561   72.363022
# 1              2   55.261497   69.506111
# 2              3   54.445557   72.900429
# 3              4   55.111008   73.805336
# 4              5   55.771336   74.529961
# ..           ...         ...         ...
# 484           84   46.618702   81.059090
# 485           85   69.490257   79.867249
# 486           86  327.342987   81.736221
# 487           87   71.842720  252.906708
# 488           88   68.784813  500.113861
#
#                                          pos  \
# 0     (74.61756134033203, 72.36302185058594)
# 1    (55.261497497558594, 69.50611114501953)
# 2       (54.445556640625, 72.90042877197266)
# 3     (55.11100769042969, 73.80533599853516)
# 4     (55.77133560180664, 74.52996063232422)
# ..                                       ...
# 484   (46.61870193481445, 81.05908966064453)
# 485    (69.4902572631836, 79.86724853515625)
# 486   (327.3429870605469, 81.73622131347656)
# 487  (71.84272003173828, 252.90670776367188)
# 488    (68.7848129272461, 500.1138610839844)
#
#                                             image_path  \
# 0    ./linda_storage/processed_books_extracted_tabl...
# 1    ./linda_storage/processed_books_extracted_tabl...
# 2    ./linda_storage/processed_books_extracted_tabl...
# 3    ./linda_storage/processed_books_extracted_tabl...
# 4    ./linda_storage/processed_books_extracted_tabl...
# ..                                                 ...
# 484  ./linda_storage/processed_books_extracted_tabl...
# 485  ./linda_storage/processed_books_extracted_tabl...
# 486  ./linda_storage/processed_books_extracted_tabl...
# 487  ./linda_storage/processed_books_extracted_tabl...
# 488  ./linda_storage/processed_books_extracted_tabl...
#
#                                               csv_path
# 0    ./linda_storage/processed_books_extracted_tabl...
# 1    ./linda_storage/processed_books_extracted_tabl...
# 2    ./linda_storage/processed_books_extracted_tabl...
# 3    ./linda_storage/processed_books_extracted_tabl...
# 4    ./linda_storage/processed_books_extracted_tabl...
# ..                                                 ...
# 484  ./linda_storage/processed_books_extracted_tabl...
# 485  ./linda_storage/processed_books_extracted_tabl...
# 486  ./linda_storage/processed_books_extracted_tabl...
# 487  ./linda_storage/processed_books_extracted_tabl...
# 488  ./linda_storage/processed_books_extracted_tabl...
#
# [489 rows x 8 columns]
